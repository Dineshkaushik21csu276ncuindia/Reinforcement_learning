# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshkaushik21csu276ncuindia/Reinforcement_learning/blob/main/Copy_of_corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import random
import seaborn as sns
import matplotlib.pyplot as plt
import random
np.random.seed(1)

# %%
X = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

# %%
plt.scatter(X,y)
print(np.corrcoef(X,y))
plt.show()
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
x = np.random.randint(0, 50, 1000)

# %%
y = x + np.random.normal(0, 10, 1000)
y = x + np.random.normal(0, 10, 1000)

# %%
# %matplotlib inline
plt.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
p = np.array([1,2,3,4,5])
q = np.array([5,4,3,2,1])

# %%
plt.scatter(p,q)
print(np.corrcoef(p,q))
plt.show()
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
x = np.random.randint(0, 50, 1000)
y = 100 - x + np.random.normal(0, 5, 1000)
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94615861],
#        [-0.94615861,  1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
p1 = np.array([1,8,35,14,5])
q2 = np.array([5,34,73,22,11])

# %%
plt.scatter(p1,q2)
print(np.corrcoef(p1,q2))
plt.show()
# Out:
# [[1.         0.94693346]
#  [0.94693346 1.        ]]

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.02870485],
#        [0.02870485, 1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000)
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 1000)
df['d'] = np.random.randint(0, 50, 1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.819319 -0.949277 -0.033036
# b  0.819319  1.000000 -0.778370 -0.025267
# c -0.949277 -0.778370  1.000000  0.048537
# d -0.033036 -0.025267  0.048537  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6, 6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
